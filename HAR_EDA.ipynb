# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.
#
# ## How data was recorded
#
# By using the sensors(Gyroscope and accelerometer) in a smartphone, they have captured '3-axial linear acceleration'(_tAcc-XYZ_) from accelerometer and '3-axial angular velocity' (_tGyro-XYZ_) from Gyroscope with several variations.
#
# > prefix 't' in those metrics denotes time.
#
# > suffix 'XYZ' represents 3-axial signals in X , Y, and Z directions.
#
# ### Feature names
#
# 1. These sensor signals are preprocessed by applying noise filters and then sampled in fixed-width windows(sliding windows) of 2.56 seconds each with 50% overlap. ie., each window has 128 readings.
#
# 2. From Each window, a feature vector was obtianed by calculating variables from the time and frequency domain.
# > In our dataset, each datapoint represents a window with different readings
# 3. The accelertion signal was saperated into Body and Gravity acceleration signals(___tBodyAcc-XYZ___ and ___tGravityAcc-XYZ___) using some low pass filter with corner frequecy of 0.3Hz.
#
# 4. After that, the body linear acceleration and angular velocity were derived in time to obtian _jerk signals_ (___tBodyAccJerk-XYZ___ and ___tBodyGyroJerk-XYZ___).
#
# 5. The magnitude of these 3-dimensional signals were calculated using the Euclidian norm. This magnitudes are represented as features with names like _tBodyAccMag_, _tGravityAccMag_, _tBodyAccJerkMag_, _tBodyGyroMag_ and _tBodyGyroJerkMag_.
#
# 6. Finally, We've got frequency domain signals from some of the available signals by applying a FFT (Fast Fourier Transform). These signals obtained were labeled with ___prefix 'f'___ just like original signals with ___prefix 't'___. These signals are labeled as ___fBodyAcc-XYZ___, ___fBodyGyroMag___ etc.,.
#
# 7. These are the signals that we got so far.
# 	+ tBodyAcc-XYZ
# 	+ tGravityAcc-XYZ
# 	+ tBodyAccJerk-XYZ
# 	+ tBodyGyro-XYZ
# 	+ tBodyGyroJerk-XYZ
# 	+ tBodyAccMag
# 	+ tGravityAccMag
# 	+ tBodyAccJerkMag
# 	+ tBodyGyroMag
# 	+ tBodyGyroJerkMag
# 	+ fBodyAcc-XYZ
# 	+ fBodyAccJerk-XYZ
# 	+ fBodyGyro-XYZ
# 	+ fBodyAccMag
# 	+ fBodyAccJerkMag
# 	+ fBodyGyroMag
# 	+ fBodyGyroJerkMag
#
# 8. We can esitmate some set of variables from the above signals. ie., We will estimate the following properties on each and every signal that we recoreded so far.
#
# 	+ ___mean()___: Mean value
# 	+ ___std()___: Standard deviation
# 	+ ___mad()___: Median absolute deviation
# 	+ ___max()___: Largest value in array
# 	+ ___min()___: Smallest value in array
# 	+ ___sma()___: Signal magnitude area
# 	+ ___energy()___: Energy measure. Sum of the squares divided by the number of values.
# 	+ ___iqr()___: Interquartile range
# 	+ ___entropy()___: Signal entropy
# 	+ ___arCoeff()___: Autorregresion coefficients with Burg order equal to 4
# 	+ ___correlation()___: correlation coefficient between two signals
# 	+ ___maxInds()___: index of the frequency component with largest magnitude
# 	+ ___meanFreq()___: Weighted average of the frequency components to obtain a mean frequency
# 	+ ___skewness()___: skewness of the frequency domain signal
# 	+ ___kurtosis()___: kurtosis of the frequency domain signal
# 	+ ___bandsEnergy()___: Energy of a frequency interval within the 64 bins of the FFT of each window.
# 	+ ___angle()___: Angle between to vectors.
#
# 9. We can obtain some other vectors by taking the average of signals in a single window sample. These are used on the angle() variable'
# `
# 	+ gravityMean
# 	+ tBodyAccMean
# 	+ tBodyAccJerkMean
# 	+ tBodyGyroMean
# 	+ tBodyGyroJerkMean
#
#
# ###  Y_Labels(Encoded)
# + In the dataset, Y_labels are represented as numbers from 1 to 6 as their identifiers.
#
# 	- WALKING as __1__
# 	- WALKING_UPSTAIRS as __2__
# 	- WALKING_DOWNSTAIRS as __3__
# 	- SITTING as __4__
# 	- STANDING as __5__
# 	- LAYING as __6__
#
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#
# ## Data
#
# * All the data is present in 'UCI_HAR_Dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_Dataset/train/X_train.txt'
#          - 'UCI_HAR_Dataset/train/subject_train.txt'
#          - 'UCI_HAR_Dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_Dataset/test/X_test.txt'
#          - 'UCI_HAR_Dataset/test/subject_test.txt'
#          - 'UCI_HAR_Dataset/test/y_test.txt'
#
#
# ## Data Size :
# > 27 MB

# %% [markdown]
# # Quick overview of the dataset :

# %% [markdown]
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.
#
# ## Problem Framework
#
# * 30 subjects(volunteers) data is randomly split to 70%(21) test and 30%(7) train data.
# * Each datapoint corresponds one of the 6 Activities.

# %% [markdown]
# ## Problem Statement
#
#  + Given a new datapoint we have to predict the Activity

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    features = [line.split()[1] for line in f.readlines()]
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %% [markdown]
# ## Obtain the  train data

# %%
# get the data from txt files to pandas dataffame
#X_train = pd.read_csv('UCI_HAR_Dataset/train/X_train.txt', delim_whitespace=True, header=None, names=features)
X_train = pd.read_csv('UCI_HAR_Dataset/train/X_train.txt',delim_whitespace=True, header=None, encoding='latin-1')
X_train.columns = features
# add subject column to the dataframe
X_train['subject'] = pd.read_csv('UCI_HAR_Dataset/train/subject_train.txt', header=None)

y_train = pd.read_csv('UCI_HAR_Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 4387           0.274728          -0.028569          -0.115659
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 4387         -0.997525         -0.953658         -0.988862          -0.99797
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 4387         -0.962755         -0.988998         -0.944162  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 4387                    -0.021181                             -0.060794
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 4387                         -0.630083                             -0.104813
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 4387             -0.818063              0.215321             -0.029568
#
#       subject  Activity  ActivityName
# 4387       22         5      STANDING
#
# [1 rows x 564 columns]

# %%
train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ## Obtain the  test data

# %%
# get the data from txt files to pandas dataffame
#X_test = pd.read_csv('UCI_HAR_Dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)
X_test = pd.read_csv('UCI_HAR_Dataset/test/X_test.txt',delim_whitespace=True, header=None, encoding='latin-1')
X_test.columns = features
# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_Dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 1371           0.277538          -0.018087           -0.12185
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 1371         -0.997143         -0.973144         -0.987617         -0.997792
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 1371         -0.970482         -0.987003         -0.938504  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 1371                    -0.002001                              0.151024
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 1371                          0.881027                             -0.051196
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 1371             -0.804243              0.233366                0.0128
#
#       subject  Activity  ActivityName
# 1371       12         5      STANDING
#
# [1 rows x 564 columns]

# %%
test.shape
# Out:
# (2947, 564)

# %% [markdown]
# # Finding out the categorical columns present in the dataset

# %%
train.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['ActivityName']

# %%
test.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['ActivityName']

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1. Check for Duplicates

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %% [markdown]
# ## 2. Checking for NaN/null values

# %%
print('We have {} NaN/Null values in train'.format(train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %% [markdown]
# ## 3. Check for data imbalance

# %% [markdown]
# ### Plotting of graphs and finding out the relations between values.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
# graph representing count of no. of times different acitivties performed by 30 subjects.
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# > We have got almost same number of reading from all the subjects

# %%
train.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# 25%           -0.992754         -0.978129         -0.980233         -0.993591
# 50%           -0.946196         -0.851897         -0.859365         -0.950709
# 75%           -0.242813         -0.034231         -0.262415         -0.292680
# max            1.000000          0.916238          1.000000          1.000000
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       7352.000000       7352.000000       7352.000000  ...
# mean          -0.526907         -0.606150         -0.468604  ...
# std            0.485942          0.414122          0.544547  ...
# min           -1.000000         -1.000000         -1.000000  ...
# 25%           -0.978162         -0.980251         -0.936219  ...
# 50%           -0.857328         -0.857143         -0.881637  ...
# 75%           -0.066701         -0.265671         -0.017129  ...
# max            0.967664          1.000000          1.000000  ...
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      7352.000000                  7352.000000
# mean                         -0.625294                     0.008684
# std                           0.307584                     0.336787
# min                          -0.999765                    -0.976580
# 25%                          -0.845573                    -0.121527
# 50%                          -0.711692                     0.009509
# 75%                          -0.503878                     0.150865
# max                           0.956845                     1.000000
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           7352.000000                       7352.000000
# mean                               0.002186                          0.008726
# std                                0.448306                          0.608303
# min                               -1.000000                         -1.000000
# 25%                               -0.289549                         -0.482273
# 50%                                0.008943                          0.008735
# 75%                                0.292861                          0.506187
# max                                1.000000                          0.998702
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           7352.000000           7352.000000
# mean                              -0.005981             -0.489547
# std                                0.477975              0.511807
# min                               -1.000000             -1.000000
# 25%                               -0.376341             -0.812065
# 50%                               -0.000368             -0.709417
# 75%                                0.359368             -0.509079
# max                                0.996078              1.000000
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)      subject     Activity
# count           7352.000000           7352.000000  7352.000000  7352.000000
# mean               0.058593             -0.056515    17.413085     3.643362
# std                0.297480              0.279122     8.975143     1.744802
# min               -1.000000             -1.000000     1.000000     1.000000
# 25%               -0.017885             -0.143414     8.000000     2.000000
# 50%                0.182071              0.003181    19.000000     4.000000
# 75%                0.248353              0.107659    26.000000     5.000000
# max                0.478157              1.000000    30.000000     6.000000
#
# [8 rows x 563 columns]

# %%
test.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        2947.000000        2947.000000        2947.000000
# mean            0.273996          -0.017863          -0.108386
# std             0.060570           0.025745           0.042747
# min            -0.592004          -0.362884          -0.576184
# 25%             0.262075          -0.024961          -0.121162
# 50%             0.277113          -0.016967          -0.108458
# 75%             0.288097          -0.010143          -0.097123
# max             0.671887           0.246106           0.494114
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       2947.000000       2947.000000       2947.000000       2947.000000
# mean          -0.613635         -0.508330         -0.633797         -0.641278
# std            0.412597          0.494269          0.362699          0.385199
# min           -0.999606         -1.000000         -0.998955         -0.999417
# 25%           -0.990914         -0.973664         -0.976122         -0.992333
# 50%           -0.931214         -0.790972         -0.827534         -0.937664
# 75%           -0.267395         -0.105919         -0.311432         -0.321719
# max            0.465299          1.000000          0.489703          0.439657
#
#        tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# count       2947.000000       2947.000000       2947.000000  ...
# mean          -0.522676         -0.637038         -0.462063  ...
# std            0.479899          0.357753          0.523916  ...
# min           -0.999914         -0.998899         -0.952357  ...
# 25%           -0.974131         -0.975352         -0.934447  ...
# 50%           -0.799907         -0.817005         -0.852659  ...
# 75%           -0.133488         -0.322771         -0.009965  ...
# max            1.000000          0.427958          0.786436  ...
#
#        fBodyBodyGyroJerkMag-kurtosis()  angle(tBodyAccMean,gravity)  \
# count                      2947.000000                  2947.000000
# mean                         -0.598756                     0.005264
# std                           0.311042                     0.336147
# min                          -1.000000                    -1.000000
# 25%                          -0.829593                    -0.130541
# 50%                          -0.683672                     0.005188
# 75%                          -0.458332                     0.146200
# max                           1.000000                     0.998898
#
#        angle(tBodyAccJerkMean),gravityMean)  angle(tBodyGyroMean,gravityMean)  \
# count                           2947.000000                       2947.000000
# mean                               0.003799                          0.040029
# std                                0.445077                          0.634989
# min                               -0.993402                         -0.998898
# 25%                               -0.282600                         -0.518924
# 50%                                0.006767                          0.047113
# 75%                                0.288113                          0.622151
# max                                0.986347                          1.000000
#
#        angle(tBodyGyroJerkMean,gravityMean)  angle(X,gravityMean)  \
# count                           2947.000000           2947.000000
# mean                              -0.017298             -0.513923
# std                                0.501311              0.509205
# min                               -0.991096             -0.984195
# 25%                               -0.428375             -0.829722
# 50%                               -0.026726             -0.729648
# 75%                                0.394387             -0.545939
# max                                1.000000              0.833180
#
#        angle(Y,gravityMean)  angle(Z,gravityMean)      subject     Activity
# count           2947.000000           2947.000000  2947.000000  2947.000000
# mean               0.074886             -0.048720    12.986427     3.577876
# std                0.324300              0.241467     6.950984     1.740348
# min               -0.913704             -0.949228     2.000000     1.000000
# 25%                0.022140             -0.098485     9.000000     2.000000
# 50%                0.181563             -0.010671    12.000000     4.000000
# 75%                0.260252              0.092373    18.000000     5.000000
# max                1.000000              0.973113    24.000000     6.000000
#
# [8 rows x 563 columns]

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Observation
# > Our data is well balanced (almost)

# %% [markdown]
# ## 4. Changing feature names

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'angletBodyAccMeangravity', 'angletBodyAccJerkMeangravityMean',
#        'angletBodyGyroMeangravityMean', 'angletBodyGyroJerkMeangravityMean',
#        'angleXgravityMean', 'angleYgravityMean', 'angleZgravityMean',
#        'subject', 'Activity', 'ActivityName'],
#       dtype='object', length=564)

# %% [markdown]
# ## 5. Save this dataframe in a csv files

# %%
train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %%
train
# Out:
#       tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0          0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1          0.278419      -0.016411      -0.123520     -0.998245     -0.975300
# 2          0.279653      -0.019467      -0.113462     -0.995380     -0.967187
# 3          0.279174      -0.026201      -0.123283     -0.996091     -0.983403
# 4          0.276629      -0.016570      -0.115362     -0.998139     -0.980817
# ...             ...            ...            ...           ...           ...
# 7347       0.299665      -0.057193      -0.181233     -0.195387      0.039905
# 7348       0.273853      -0.007749      -0.147468     -0.235309      0.004816
# 7349       0.273387      -0.017011      -0.045022     -0.218218     -0.103822
# 7350       0.289654      -0.018843      -0.158281     -0.219139     -0.111412
# 7351       0.351503      -0.012423      -0.203867     -0.269270     -0.087212
#
#       tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  \
# 0        -0.913526     -0.995112     -0.983185     -0.923527     -0.934724
# 1        -0.960322     -0.998807     -0.974914     -0.957686     -0.943068
# 2        -0.978944     -0.996520     -0.963668     -0.977469     -0.938692
# 3        -0.990675     -0.997099     -0.982750     -0.989302     -0.938692
# 4        -0.990482     -0.998321     -0.979672     -0.990441     -0.942469
# ...            ...           ...           ...           ...           ...
# 7347      0.077078     -0.282301      0.043616      0.060410      0.210795
# 7348      0.059280     -0.322552     -0.029456      0.080585      0.117440
# 7349      0.274533     -0.304515     -0.098913      0.332584      0.043999
# 7350      0.268893     -0.310487     -0.068200      0.319473      0.101702
# 7351      0.177404     -0.377404     -0.038678      0.229430      0.269013
#
#       ...  angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0     ...                 -0.112754                          0.030400
# 1     ...                  0.053477                         -0.007435
# 2     ...                 -0.118559                          0.177899
# 3     ...                 -0.036788                         -0.012892
# 4     ...                  0.123320                          0.122542
# ...   ...                       ...                               ...
# 7347  ...                 -0.190437                          0.829718
# 7348  ...                  0.064907                          0.875679
# 7349  ...                  0.052806                         -0.266724
# 7350  ...                 -0.101360                          0.700740
# 7351  ...                 -0.280088                         -0.007739
#
#       angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                         -0.464761                          -0.018446
# 1                         -0.732626                           0.703511
# 2                          0.100699                           0.808529
# 3                          0.640011                          -0.485366
# 4                          0.693578                          -0.615971
# ...                             ...                                ...
# 7347                       0.206972                          -0.425619
# 7348                      -0.879033                           0.400219
# 7349                       0.864404                           0.701169
# 7350                       0.936674                          -0.589479
# 7351                      -0.056088                          -0.616956
#
#       angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  \
# 0             -0.841247           0.179941          -0.058627        1
# 1             -0.844788           0.180289          -0.054317        1
# 2             -0.848933           0.180637          -0.049118        1
# 3             -0.848649           0.181935          -0.047663        1
# 4             -0.847865           0.185151          -0.043892        1
# ...                 ...                ...                ...      ...
# 7347          -0.791883           0.238604           0.049819       30
# 7348          -0.771840           0.252676           0.050053       30
# 7349          -0.779133           0.249145           0.040811       30
# 7350          -0.785181           0.246432           0.025339       30
# 7351          -0.783267           0.246809           0.036695       30
#
#       Activity      ActivityName
# 0            5          STANDING
# 1            5          STANDING
# 2            5          STANDING
# 3            5          STANDING
# 4            5          STANDING
# ...        ...               ...
# 7347         2  WALKING_UPSTAIRS
# 7348         2  WALKING_UPSTAIRS
# 7349         2  WALKING_UPSTAIRS
# 7350         2  WALKING_UPSTAIRS
# 7351         2  WALKING_UPSTAIRS
#
# [7352 rows x 564 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# "___Without domain knowledge EDA has no meaning, without EDA a problem has no soul.___"

# %% [markdown]
# ### 1. Featuring Engineering from Domain Knowledge

# %% [markdown]
# + __Static and Dynamic Activities__
#
#     - In static activities (sit, stand, lie down) motion information will not be very useful.
# 	- In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ### 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()

# %% [markdown]
# #### In the above graph, TBodyAccMagMean depicts as an important feature because it easily differentiates idle activities and moving activities (Example: if Value lies between -1 and -0.5 then we can say it can be idle activity else it is moving activity.

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['Activity']==1]
df2 = train[train['Activity']==2]
df3 = train[train['Activity']==3]
df4 = train[train['Activity']==4]
df5 = train[train['Activity']==5]
df6 = train[train['Activity']==6]

plt.figure(figsize=(14,7))
plt.subplot(2,2,1)
plt.title('Stationary Activities(Zoomed in)')
sns.distplot(df4['tBodyAccMagmean'],color = 'r',hist = False, label = 'Sitting')
sns.distplot(df5['tBodyAccMagmean'],color = 'm',hist = False,label = 'Standing')
sns.distplot(df6['tBodyAccMagmean'],color = 'c',hist = False, label = 'Laying')
plt.axis([-1.01, -0.5, 0, 35])
plt.legend(loc='center')

plt.subplot(2,2,2)
plt.title('Moving Activities')
sns.distplot(df1['tBodyAccMagmean'],color = 'red',hist = False, label = 'Walking')
sns.distplot(df2['tBodyAccMagmean'],color = 'blue',hist = False,label = 'Walking Up')
sns.distplot(df3['tBodyAccMagmean'],color = 'green',hist = False, label = 'Walking down')
plt.legend(loc='center right')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3. Magnitude of an acceleration can saperate it well

# %%
#Graph depicting the relation mean of Accleration magnitude and activities.
#Univarient Analysis 
#Feature 'tBodyAccMagmean'
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# __ Observations__:
# - If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# - If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# - If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# - We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ### 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# __ Observations__:
# * If angleX,gravityMean > 0 then Activity is Laying.
# * We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='ActivityName', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Finding the Correlation/relationships between the features

# %%
feature_cols = train.columns[: -1]   #exclude the ActivityName column
#Calculate the correlation values
correlated_values = train[feature_cols].corr()
#stack the data and convert to a dataframe
correlated_values = (correlated_values.stack().to_frame().reset_index()
                    .rename(columns={'level_0': 'Feature_1', 'level_1': 'Feature_2', 0:'Correlations'}))
correlated_values.head()
# Out:
#        Feature_1      Feature_2  Correlations
# 0  tBodyAccmeanX  tBodyAccmeanX      1.000000
# 1  tBodyAccmeanX  tBodyAccmeanY      0.148061
# 2  tBodyAccmeanX  tBodyAccmeanZ     -0.256952
# 3  tBodyAccmeanX   tBodyAccstdX      0.000619
# 4  tBodyAccmeanX   tBodyAccstdY     -0.021903

# %%
correlated_values[correlated_values['Correlations']>0.8]
# Out:
#                 Feature_1           Feature_2  Correlations
# 0           tBodyAccmeanX       tBodyAccmeanX      1.000000
# 816         tBodyAccmeanY       tBodyAccmeanY      1.000000
# 1632        tBodyAccmeanZ       tBodyAccmeanZ      1.000000
# 2448         tBodyAccstdX        tBodyAccstdX      1.000000
# 2449         tBodyAccstdX        tBodyAccstdY      0.927461
# ...                   ...                 ...           ...
# 661021  angleYgravityMean  tGravityAccenergyX      0.822097
# 661776  angleYgravityMean   angleYgravityMean      1.000000
# 662592  angleZgravityMean   angleZgravityMean      1.000000
# 663408            subject             subject      1.000000
# 664224           Activity            Activity      1.000000
#
# [62663 rows x 3 columns]

# %%
#correlation= (x-xbar)(y-ybar)/sigmax*sigmay

# %% [markdown]
# # Apply t-sne on the data

# %%
#MultiVariate feature analysis (TSNE) over all
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## t-sne helps to visulalize higher dimension data by projecting into lower dimensions

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.001s...
# [t-SNE] Computed neighbors for 7352 samples in 1.104s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.597443
# [t-SNE] Computed conditional probabilities in 0.015s
# [t-SNE] Iteration 50: error = 124.8589935, gradient norm = 0.0239699 (50 iterations in 0.983s)
# [t-SNE] Iteration 100: error = 107.0941467, gradient norm = 0.0296299 (50 iterations in 0.671s)
# [t-SNE] Iteration 150: error = 100.9009399, gradient norm = 0.0227792 (50 iterations in 0.603s)
# [t-SNE] Iteration 200: error = 97.5354462, gradient norm = 0.0203095 (50 iterations in 0.593s)
# [t-SNE] Iteration 250: error = 95.2196579, gradient norm = 0.0148791 (50 iterations in 0.596s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.219658
# [t-SNE] Iteration 300: error = 4.1215935, gradient norm = 0.0015714 (50 iterations in 0.593s)
# [t-SNE] Iteration 350: error = 3.2102141, gradient norm = 0.0010011 (50 iterations in 0.611s)
# [t-SNE] Iteration 400: error = 2.7778704, gradient norm = 0.0007192 (50 iterations in 0.660s)
# [t-SNE] Iteration 450: error = 2.5132127, gradient norm = 0.0005679 (50 iterations in 0.623s)
# [t-SNE] Iteration 500: error = 2.3290291, gradient norm = 0.0004824 (50 iterations in 0.597s)
# [t-SNE] Iteration 550: error = 2.1906247, gradient norm = 0.0004153 (50 iterations in 0.621s)
# [t-SNE] Iteration 600: error = 2.0811450, gradient norm = 0.0003658 (50 iterations in 0.629s)
# [t-SNE] Iteration 650: error = 1.9911633, gradient norm = 0.0003267 (50 iterations in 0.660s)
# [t-SNE] Iteration 700: error = 1.9156330, gradient norm = 0.0003024 (50 iterations in 0.668s)
# [t-SNE] Iteration 750: error = 1.8504398, gradient norm = 0.0002788 (50 iterations in 0.664s)
# [t-SNE] Iteration 800: error = 1.7935300, gradient norm = 0.0002565 (50 iterations in 0.656s)
# [t-SNE] Iteration 850: error = 1.7433300, gradient norm = 0.0002383 (50 iterations in 0.665s)
# [t-SNE] Iteration 900: error = 1.6987793, gradient norm = 0.0002268 (50 iterations in 0.661s)
# [t-SNE] Iteration 950: error = 1.6586173, gradient norm = 0.0002095 (50 iterations in 0.662s)
# [t-SNE] Iteration 1000: error = 1.6223923, gradient norm = 0.0001998 (50 iterations in 0.666s)
# [t-SNE] KL divergence after 1000 iterations: 1.622392
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.001s...
# [t-SNE] Computed neighbors for 7352 samples in 1.085s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961446
# [t-SNE] Computed conditional probabilities in 0.020s
# [t-SNE] Iteration 50: error = 114.1808472, gradient norm = 0.0204385 (50 iterations in 0.947s)
# [t-SNE] Iteration 100: error = 97.9745178, gradient norm = 0.0166078 (50 iterations in 0.727s)
# [t-SNE] Iteration 150: error = 93.4780579, gradient norm = 0.0162964 (50 iterations in 0.661s)
# [t-SNE] Iteration 200: error = 91.4625702, gradient norm = 0.0074569 (50 iterations in 0.643s)
# [t-SNE] Iteration 250: error = 90.2554092, gradient norm = 0.0082346 (50 iterations in 0.675s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.255409
# [t-SNE] Iteration 300: error = 3.5795276, gradient norm = 0.0014687 (50 iterations in 0.638s)
# [t-SNE] Iteration 350: error = 2.8193507, gradient norm = 0.0007482 (50 iterations in 0.651s)
# [t-SNE] Iteration 400: error = 2.4380026, gradient norm = 0.0005288 (50 iterations in 0.640s)
# [t-SNE] Iteration 450: error = 2.2208838, gradient norm = 0.0004072 (50 iterations in 0.680s)
# [t-SNE] Iteration 500: error = 2.0759895, gradient norm = 0.0003321 (50 iterations in 0.696s)
# [t-SNE] Iteration 550: error = 1.9705049, gradient norm = 0.0002828 (50 iterations in 0.644s)
# [t-SNE] Iteration 600: error = 1.8894753, gradient norm = 0.0002475 (50 iterations in 0.659s)
# [t-SNE] Iteration 650: error = 1.8244438, gradient norm = 0.0002196 (50 iterations in 0.654s)
# [t-SNE] Iteration 700: error = 1.7707050, gradient norm = 0.0001984 (50 iterations in 0.648s)
# [t-SNE] Iteration 750: error = 1.7253200, gradient norm = 0.0001818 (50 iterations in 0.610s)
# [t-SNE] Iteration 800: error = 1.6863484, gradient norm = 0.0001651 (50 iterations in 0.594s)
# [t-SNE] Iteration 850: error = 1.6525319, gradient norm = 0.0001540 (50 iterations in 0.600s)
# [t-SNE] Iteration 900: error = 1.6226668, gradient norm = 0.0001427 (50 iterations in 0.626s)
# [t-SNE] Iteration 950: error = 1.5961399, gradient norm = 0.0001338 (50 iterations in 0.629s)
# [t-SNE] Iteration 1000: error = 1.5724018, gradient norm = 0.0001249 (50 iterations in 0.669s)
# [t-SNE] KL divergence after 1000 iterations: 1.572402
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.001s...
# [t-SNE] Computed neighbors for 7352 samples in 1.133s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133827
# [t-SNE] Computed conditional probabilities in 0.038s
# [t-SNE] Iteration 50: error = 105.9044647, gradient norm = 0.0172718 (50 iterations in 0.970s)
# [t-SNE] Iteration 100: error = 90.9784546, gradient norm = 0.0096978 (50 iterations in 0.800s)
# [t-SNE] Iteration 150: error = 87.4615936, gradient norm = 0.0063446 (50 iterations in 0.680s)
# [t-SNE] Iteration 200: error = 86.1579971, gradient norm = 0.0046281 (50 iterations in 0.689s)
# [t-SNE] Iteration 250: error = 85.3937225, gradient norm = 0.0060493 (50 iterations in 0.692s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.393723
# [t-SNE] Iteration 300: error = 3.1298358, gradient norm = 0.0013856 (50 iterations in 0.674s)
# [t-SNE] Iteration 350: error = 2.4882693, gradient norm = 0.0006443 (50 iterations in 0.609s)
# [t-SNE] Iteration 400: error = 2.1701889, gradient norm = 0.0004229 (50 iterations in 0.612s)
# [t-SNE] Iteration 450: error = 1.9868932, gradient norm = 0.0003134 (50 iterations in 0.609s)
# [t-SNE] Iteration 500: error = 1.8691640, gradient norm = 0.0002504 (50 iterations in 0.685s)
# [t-SNE] Iteration 550: error = 1.7860186, gradient norm = 0.0002100 (50 iterations in 0.702s)
# [t-SNE] Iteration 600: error = 1.7236193, gradient norm = 0.0001801 (50 iterations in 0.647s)
# [t-SNE] Iteration 650: error = 1.6742249, gradient norm = 0.0001606 (50 iterations in 0.661s)
# [t-SNE] Iteration 700: error = 1.6345031, gradient norm = 0.0001445 (50 iterations in 0.607s)
# [t-SNE] Iteration 750: error = 1.6020567, gradient norm = 0.0001303 (50 iterations in 0.643s)
# [t-SNE] Iteration 800: error = 1.5745654, gradient norm = 0.0001199 (50 iterations in 0.643s)
# [t-SNE] Iteration 850: error = 1.5512657, gradient norm = 0.0001098 (50 iterations in 0.662s)
# [t-SNE] Iteration 900: error = 1.5311027, gradient norm = 0.0001022 (50 iterations in 0.642s)
# [t-SNE] Iteration 950: error = 1.5134938, gradient norm = 0.0000966 (50 iterations in 0.670s)
# [t-SNE] Iteration 1000: error = 1.4980868, gradient norm = 0.0000922 (50 iterations in 0.691s)
# [t-SNE] KL divergence after 1000 iterations: 1.498087
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.001s...
# [t-SNE] Computed neighbors for 7352 samples in 1.134s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274336
# [t-SNE] Computed conditional probabilities in 0.074s
# [t-SNE] Iteration 50: error = 97.3013992, gradient norm = 0.0227532 (50 iterations in 1.010s)
# [t-SNE] Iteration 100: error = 84.3376999, gradient norm = 0.0066779 (50 iterations in 0.900s)
# [t-SNE] Iteration 150: error = 82.0659790, gradient norm = 0.0041605 (50 iterations in 0.844s)
# [t-SNE] Iteration 200: error = 81.2874908, gradient norm = 0.0024785 (50 iterations in 0.836s)
# [t-SNE] Iteration 250: error = 80.8806686, gradient norm = 0.0018243 (50 iterations in 0.855s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.880669
# [t-SNE] Iteration 300: error = 2.7051878, gradient norm = 0.0013140 (50 iterations in 0.790s)
# [t-SNE] Iteration 350: error = 2.1702409, gradient norm = 0.0005838 (50 iterations in 0.716s)
# [t-SNE] Iteration 400: error = 1.9198332, gradient norm = 0.0003512 (50 iterations in 0.723s)
# [t-SNE] Iteration 450: error = 1.7730105, gradient norm = 0.0002505 (50 iterations in 0.741s)
# [t-SNE] Iteration 500: error = 1.6785823, gradient norm = 0.0001930 (50 iterations in 0.908s)
# [t-SNE] Iteration 550: error = 1.6137807, gradient norm = 0.0001601 (50 iterations in 0.795s)
# [t-SNE] Iteration 600: error = 1.5669411, gradient norm = 0.0001356 (50 iterations in 0.740s)
# [t-SNE] Iteration 650: error = 1.5315406, gradient norm = 0.0001201 (50 iterations in 0.740s)
# [t-SNE] Iteration 700: error = 1.5046318, gradient norm = 0.0001076 (50 iterations in 0.711s)
# [t-SNE] Iteration 750: error = 1.4845521, gradient norm = 0.0000996 (50 iterations in 0.711s)
# [t-SNE] Iteration 800: error = 1.4684865, gradient norm = 0.0000939 (50 iterations in 0.733s)
# [t-SNE] Iteration 850: error = 1.4554491, gradient norm = 0.0000872 (50 iterations in 0.747s)
# [t-SNE] Iteration 900: error = 1.4443694, gradient norm = 0.0000829 (50 iterations in 0.721s)
# [t-SNE] Iteration 950: error = 1.4344004, gradient norm = 0.0000759 (50 iterations in 0.739s)
# [t-SNE] Iteration 1000: error = 1.4250708, gradient norm = 0.0000712 (50 iterations in 0.743s)
# [t-SNE] KL divergence after 1000 iterations: 1.425071
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.001s...
# [t-SNE] Computed neighbors for 7352 samples in 1.232s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.182s
# [t-SNE] Iteration 50: error = 84.6004639, gradient norm = 0.0353995 (50 iterations in 1.283s)
# [t-SNE] Iteration 100: error = 75.6054535, gradient norm = 0.0043680 (50 iterations in 1.106s)
# [t-SNE] Iteration 150: error = 74.6510239, gradient norm = 0.0035276 (50 iterations in 0.936s)
# [t-SNE] Iteration 200: error = 74.2946167, gradient norm = 0.0021720 (50 iterations in 0.969s)
# [t-SNE] Iteration 250: error = 74.1168518, gradient norm = 0.0011118 (50 iterations in 0.948s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.116852
# [t-SNE] Iteration 300: error = 2.1557477, gradient norm = 0.0011955 (50 iterations in 0.960s)
# [t-SNE] Iteration 350: error = 1.7558246, gradient norm = 0.0004864 (50 iterations in 0.947s)
# [t-SNE] Iteration 400: error = 1.5863250, gradient norm = 0.0002815 (50 iterations in 0.880s)
# [t-SNE] Iteration 450: error = 1.4923596, gradient norm = 0.0001895 (50 iterations in 0.868s)
# [t-SNE] Iteration 500: error = 1.4325693, gradient norm = 0.0001404 (50 iterations in 0.870s)
# [t-SNE] Iteration 550: error = 1.3915336, gradient norm = 0.0001111 (50 iterations in 0.878s)
# [t-SNE] Iteration 600: error = 1.3621696, gradient norm = 0.0000941 (50 iterations in 0.878s)
# [t-SNE] Iteration 650: error = 1.3410190, gradient norm = 0.0000823 (50 iterations in 0.876s)
# [t-SNE] Iteration 700: error = 1.3254099, gradient norm = 0.0000765 (50 iterations in 0.879s)
# [t-SNE] Iteration 750: error = 1.3139300, gradient norm = 0.0000703 (50 iterations in 0.867s)
# [t-SNE] Iteration 800: error = 1.3053339, gradient norm = 0.0000658 (50 iterations in 0.904s)
# [t-SNE] Iteration 850: error = 1.2982421, gradient norm = 0.0000614 (50 iterations in 0.870s)
# [t-SNE] Iteration 900: error = 1.2923826, gradient norm = 0.0000597 (50 iterations in 0.867s)
# [t-SNE] Iteration 950: error = 1.2874759, gradient norm = 0.0000552 (50 iterations in 0.881s)
# [t-SNE] Iteration 1000: error = 1.2832322, gradient norm = 0.0000551 (50 iterations in 0.848s)
# [t-SNE] KL divergence after 1000 iterations: 1.283232
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# Except sitting and standing remaining data can be clearly seperable as mentioned above graphs with the help of t-sne.

# %% [markdown]
# t-sne,perplexity and max_iter are hyper parameters
# box plot range,

# %% [markdown]
#  As there are 563 features,therefore it became a tedious task to identify important features also identifying patterns on high dimension data is very difficult but with the help of t-sne it could able to identify patterns.
